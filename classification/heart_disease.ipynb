# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("heart.csv")
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# **sex** : 1 = male; 0 = female <br>
# **cp** : chest pain type (4 values) <br>
# **trestbps** : resting blood pressure <br>
# **chol** : serum cholestoral in mg/dl <br>
# **fbs** : fasting blood sugar > 120 mg/dl (1 = true; 0 = false) <br>
# **restecg** : resting electrocardiographic results (values 0,1,2) <br>
# **thalach** : maximum heart rate achieved <br>
# **exang** : exercise induced angina (1 = yes; 0 = no) <br>
# **oldpeak** : ST depression induced by exercise relative to rest <br>
# **slope** : the slope of the peak exercise ST segment <br>
# **ca** : number of major vessels (0-3) colored by flourosopy <br>
# **thal** : 1 = normal; 2 = fixed defect; 3 = reversable defect <br>
# **target** : 1=yes or 0=no

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
sns.heatmap(data.corr(),annot=True,linewidth=0.5,linecolor="white",cmap=sns.color_palette("Spectral", as_cmap=True),fmt=".1f")
# Out:
# <Axes: >

# %%
def scatterPlot(x,y,data):
  sns.scatterplot(x=x,y=y,data=data)
  plt.title("Relationship between {} and {}".format(x,y))
  plt.show()

# %%
columns=[('age','trestbps'), ('oldpeak', 'slope'), ('cp','thalach')]
for x,y in columns:
  scatterPlot(x,y,data)

# %%
def plotHistogram(column):
  """
  Input: Column name
  Output: histogram chart of the relevant feature
  """
  plt.figure()
  plt.hist(data[column],bins=85,color="blue")
  plt.xlabel(column)
  plt.ylabel("Frequency")
  plt.title("Data Frequency - {}".format(column))
  plt.show()

# %%
columns=['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
       'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']
for i in columns:
  plotHistogram(i)

# %%
def plotBox(column):
  plt.figure()
  plt.boxplot(data[column])
  plt.xlabel(column)
  plt.ylabel("Value")
  plt.show()

# %%
for i in columns:
  plotBox(i)

# %% [markdown]
# - This is a binary classification problem because the target variable (target column) in the data set takes two different values. So let's try machine learning models suitable for binary classification.

# %% [markdown]
# **Logistic Regression**

# %%
X = data.drop('target', axis=1) # features
y = data['target'] # target variable

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8116883116883117
# [[121  38]
#  [ 20 129]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.76      0.81       159
#            1       0.77      0.87      0.82       149
#
#     accuracy                           0.81       308
#    macro avg       0.82      0.81      0.81       308
# weighted avg       0.82      0.81      0.81       308

# %% [markdown]
# **Support Vector Machines - SVM**

# %%
from sklearn.svm import SVC
model = SVC(kernel='linear')
model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = model.predict(X_test)
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8084415584415584
# [[119  40]
#  [ 19 130]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80       159
#            1       0.76      0.87      0.82       149
#
#     accuracy                           0.81       308
#    macro avg       0.81      0.81      0.81       308
# weighted avg       0.82      0.81      0.81       308

# %% [markdown]
# **GridSearchCV** is a tool used to systematically test different combinations of hyperparameters to find the best-performing set for a given model.<br> <br>
# **C:** Controls the trade-off between achieving a low training error and a low testing error. A small C value makes the model more regularized (simpler), while a large C value allows the model to fit the training data more closely, potentially leading to overfitting.<br>
# **gamma:** Defines how far the influence of a single training example reaches. High values of gamma will focus the decision boundary close to the data points, while low values make it more generalized.
# kernel: Specifies the type of kernel to be used in the SVM. The 'linear' kernel is used for linearly separable data, while the 'rbf' (Radial Basis Function) kernel is used for non-linear data.<br>
# **kernel:** Specifies the type of kernel to be used in the SVM. The 'linear' kernel is used for linearly separable data, while the 'rbf' (Radial Basis Function) kernel is used for non-linear data.

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': [1, 0.1, 0.01, 0.001],
    'kernel': ['linear', 'rbf']
}

grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=2)
grid.fit(X_train, y_train)
print(grid.best_params_)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time=   0.2s
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time=   0.5s
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time=   0.4s
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time=   0.2s
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time=   0.1s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ....................C=0.1, gamma=0.1, kernel=linear; total time=   0.2s
# ...

# %%
model2 = SVC(C=10,kernel='rbf',gamma=0.01)
model2.fit(X_train, y_train)
y_pred = model2.predict(X_test)
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9902597402597403
# [[159   0]
#  [  3 146]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       159
#            1       1.00      0.98      0.99       149
#
#     accuracy                           0.99       308
#    macro avg       0.99      0.99      0.99       308
# weighted avg       0.99      0.99      0.99       308

# %% [markdown]
# **Naive Bayes**

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9805194805194806
# [[159   0]
#  [  6 143]]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       159
#            1       1.00      0.96      0.98       149
#
#     accuracy                           0.98       308
#    macro avg       0.98      0.98      0.98       308
# weighted avg       0.98      0.98      0.98       308

# %% [markdown]
# **Decision Trees**

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test)
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9707792207792207
# [[159   0]
#  [  9 140]]
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       159
#            1       1.00      0.94      0.97       149
#
#     accuracy                           0.97       308
#    macro avg       0.97      0.97      0.97       308
# weighted avg       0.97      0.97      0.97       308

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9805194805194806
# [[159   0]
#  [  6 143]]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       159
#            1       1.00      0.96      0.98       149
#
#     accuracy                           0.98       308
#    macro avg       0.98      0.98      0.98       308
# weighted avg       0.98      0.98      0.98       308

# %% [markdown]
# **K-Nearest Neighbors (KNN)**

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model.predict(X_test)
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7142857142857143
# [[111  48]
#  [ 40 109]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.70      0.72       159
#            1       0.69      0.73      0.71       149
#
#     accuracy                           0.71       308
#    macro avg       0.71      0.71      0.71       308
# weighted avg       0.72      0.71      0.71       308

# %% [markdown]
# **Finding the best k value**

# %%
score_list=[]
for each in range(1,10):
  knn=KNeighborsClassifier(n_neighbors=each)
  knn.fit(X_train,y_train)
  score_list.append(knn.score(X_test,y_test))

plt.plot(range(1,10),score_list)
plt.xlabel("k values")
plt.ylabel("Accuracy")
plt.title("Finding The Best k Value")
plt.show()

# %%
model2 = KNeighborsClassifier(n_neighbors=4)
model2.fit(X_train, y_train)

y_pred = model2.predict(X_test)
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7954545454545454
# [[142  17]
#  [ 46 103]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.89      0.82       159
#            1       0.86      0.69      0.77       149
#
#     accuracy                           0.80       308
#    macro avg       0.81      0.79      0.79       308
# weighted avg       0.81      0.80      0.79       308

# %% [markdown]
# **Neural Networks**

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(hidden_layer_sizes=(100,), max_iter=300)
model.fit(X_train, y_train)
# Out:
# MLPClassifier(max_iter=300)

# %%
y_pred = model.predict(X_test)
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8181818181818182
# [[122  37]
#  [ 19 130]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.77      0.81       159
#            1       0.78      0.87      0.82       149
#
#     accuracy                           0.82       308
#    macro avg       0.82      0.82      0.82       308
# weighted avg       0.82      0.82      0.82       308
